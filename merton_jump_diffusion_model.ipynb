# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as ss
import scipy.optimize as opt
import math

# %%
nu = 0.05
sig = 0.2
sigJ = 0.5
lam = 1.2
nuJ = 0.15
N = 100000
T = 2

# %%
def merton_density(x, T, mu, sig, lam, nuJ, sigJ):
  total = 0
  for k in range(20):
    total += (
        (lam * T) ** k 
        * np.exp(-((x - mu * T - k * nuJ)**2) / (2 * (T * sig**2 + k * sig**2))) 
        / (math.factorial(k) * np.sqrt(2 * np.pi * (sig**2 * T + k * sigJ**2)))
    )

  return np.exp(-lam * T) * total

# %%
np.random.seed(42)

W = ss.norm.rvs(0, 1, N)
P = ss.poisson.rvs(lam*T, size=N)
Jumps = np.asarray([ss.norm.rvs(nuJ, sigJ, i).sum() for i in P])
X_T nu 8 T + np.sqrt(T) * sig * W + Jumps

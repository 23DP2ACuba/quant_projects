# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from scipy.stats import boxcox
import yfinance as yf

start="2020-01-01"
end="2025-01-01"

# %%
data = yf.Ticker("TSLA").history(start=start, end=end)

# %%
def apply_boxcox(data):
  data = data.copy()
  box_cox_transform, lmbd = boxcox(data["Close"])
  print(box_cox_transform)
  print(f"Lambda: {lmbd}")
  data["Transformed_Close_diff"] = pd.Series(box_cox_transform, index=data.index).diff()
  return  data, lmbd

def plot(data):
  plt.figure(figsize=(10,4))
  for col in ["Close", "Transformed_Close_diff"]:
    plt.plot(data[col], label=f"{col} Closing Prices")
    plt.title("Closing Prices")
    plt.xlabel("date")
    plt.ylabel("price")
    plt.legend()
    plt.show()

# %%
data, lmbd = apply_boxcox(data)
print(data)
plot(data)
